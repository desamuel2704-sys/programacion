# %% [markdown]
# # clase programacion
#
# ## clase 1
#
# ### samuel lozano
#
# Esta es la primera clase
#
# -variable
# -tipos de dato
# -print

# %%
print("hola mundo")
# Out:
# hola mundo

# %%
nombre="samuel" # String
edad=20 # Entero
tasa_interes = 0,15 # Flotante
activo = True #Booleano

# %%
print(nombre)
# Out:
# samuel

# %%
print(nombre)
print(edad)
print("\n")
print("mi nombre es" ,nombre, "y tengo", edad, "años.")
# Out:
# samuel
# 20
#
#
# mi nombre es samuel y tengo 20 años.

# %%
type(nombre)
# Out:
# bool

# %%
type(True)
# Out:
# bool

# %%
print("'hola'")
# Out:
# 'hola'

# %%
saludo = "hola " + nombre # "hola samuel"

# %%
print(saludo)
# Out:
# hola samuel
